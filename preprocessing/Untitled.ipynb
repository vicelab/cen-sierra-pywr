# %%
import pandas as pd

df = pd.read_csv('../data/energy_netDemand.csv', index_col=[0], parse_dates=True)
df.to_csv('../data/energy_net_demand.csv')
