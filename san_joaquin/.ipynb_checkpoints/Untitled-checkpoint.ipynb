# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results.csv', parse_dates=True, header=0, index_col=0, skiprows=[1])
sim = [n for n in df.columns if '/storage' in n]
obs = [n for n in df.columns if '/observed storage' in n]
fig, axes = plt.subplots(len(reservoirs), 1, figsize=(10, 30))
for i, res in enumerate(reservoirs):
    ax = axes[i]
    ax.plot(df[res])
    ax.set_title(res.split())
plt.tight_layout()
